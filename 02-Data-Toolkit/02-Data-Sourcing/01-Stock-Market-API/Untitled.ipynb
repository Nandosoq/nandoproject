# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib

# %%
import requests

url = "http://iex.lewagon.com/stable/stock/aapl/chart/3m"
api_data = requests.get(url).json()

# %%
apple_df  = pd.DataFrame(api_data)

# %% [markdown]
# Convert the date column to a datetime object
#
# Set the date column as the index

# %%
apple_df['date'] = pd.to_datetime(apple_df['date'], format='%Y-%m-%d')
apple_df.set_index('date',inplace=True)

# %% [markdown]
# First let’s plot with only the values in the close column
#
# Now we can make a plot with the values in the open, close, high, and low columns

# %%
apple_df['close'].plot()
apple_df[['open','close','high','low']].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Out:
#              close      high      low     open symbol     volume  \
# date
# 2021-04-27  134.39  135.4100  134.110  135.010   AAPL   66015804
# 2021-04-28  133.58  135.0200  133.080  134.310   AAPL  107760097
# 2021-04-29  133.48  137.0700  132.450  136.470   AAPL  151100953
# 2021-04-30  131.46  133.5600  131.065  131.780   AAPL  109839466
# 2021-05-03  132.54  134.0700  131.830  132.040   AAPL   75135100
# ...            ...       ...      ...      ...    ...        ...
# 2021-07-20  146.15  147.0997  142.960  143.460   AAPL   96350036
# 2021-07-21  145.40  146.1300  144.630  145.530   AAPL   74993460
# 2021-07-22  146.80  148.1950  145.810  145.935   AAPL   77338156
# 2021-07-23  148.56  148.7177  146.920  147.550   AAPL   71447416
# 2021-07-26  148.99  149.8300  147.700  148.270   AAPL   72434089
#
#                            id   key subkey        updated  ...     uLow  \
# date                                                       ...
# 2021-04-27  HISTORICAL_PRICES  AAPL         1620357389000  ...  134.110
# 2021-04-28  HISTORICAL_PRICES  AAPL         1620357411000  ...  133.080
# 2021-04-29  HISTORICAL_PRICES  AAPL         1620357525000  ...  132.450
# 2021-04-30  HISTORICAL_PRICES  AAPL         1620357432000  ...  131.065
# 2021-05-03  HISTORICAL_PRICES  AAPL         1620357456000  ...  131.830
# ...                       ...   ...    ...            ...  ...      ...
# 2021-07-20  HISTORICAL_PRICES  AAPL         1626829533000  ...  142.960
# 2021-07-21  HISTORICAL_PRICES  AAPL         1626915750000  ...  144.630
# 2021-07-22  HISTORICAL_PRICES  AAPL         1627001611000  ...  145.810
# 2021-07-23  HISTORICAL_PRICES  AAPL         1627089465000  ...  146.920
# 2021-07-26  HISTORICAL_PRICES  AAPL         1627346887000  ...  147.700
#
#               uVolume     fOpen    fClose     fHigh      fLow    fVolume  \
# date
# 2021-04-27   66015804  134.7811  134.1621  135.1804  133.8826   66015804
# 2021-04-28  107760097  134.0823  133.3535  134.7910  132.8543  107760097
# 2021-04-29  151100953  136.2386  133.2537  136.8376  132.2254  151100953
# 2021-04-30  109839466  131.5565  131.2371  133.3335  130.8428  109839466
# 2021-05-03   75135100  131.8161  132.3153  133.8427  131.6065   75135100
# ...               ...       ...       ...       ...       ...        ...
# 2021-07-20   96350036  143.4600  146.1500  147.0997  142.9600   96350036
# 2021-07-21   74993460  145.5300  145.4000  146.1300  144.6300   74993460
# 2021-07-22   77338156  145.9350  146.8000  148.1950  145.8100   77338156
# 2021-07-23   71447416  147.5500  148.5600  148.7177  146.9200   71447416
# 2021-07-26   72434089  148.2700  148.9900  149.8300  147.7000   72434089
#
#                  label  change  changePercent
# date
# 2021-04-27  Apr 27, 21    0.00         0.0000
# 2021-04-28  Apr 28, 21   -0.81        -0.0060
# 2021-04-29  Apr 29, 21   -0.10        -0.0007
# 2021-04-30  Apr 30, 21   -2.02        -0.0151
# 2021-05-03   May 3, 21    1.08         0.0082
# ...                ...     ...            ...
# 2021-07-20  Jul 20, 21    3.70         0.0260
# 2021-07-21  Jul 21, 21   -0.75        -0.0051
# 2021-07-22  Jul 22, 21    1.40         0.0096
# 2021-07-23  Jul 23, 21    1.76         0.0120
# 2021-07-26  Jul 26, 21    0.43         0.0029
#
# [63 rows x 25 columns]
