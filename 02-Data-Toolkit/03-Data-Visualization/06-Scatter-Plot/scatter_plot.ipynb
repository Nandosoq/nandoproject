# %% [markdown]
# # Scatter Plots

# %%
# imports here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# import and explore the dataset

gdp_df = pd.read_csv('4_ThreeNum.csv')
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    142 non-null    object
#  1   continent  142 non-null    object
#  2   lifeExp    142 non-null    float64
#  3   pop        142 non-null    int64
#  4   gdpPercap  142 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 5.7+ KB

# %%
gdp_df.head()
# Out:
#        country continent  lifeExp       pop     gdpPercap
# 0  Afghanistan      Asia   43.828  31889923    974.580338
# 1      Albania    Europe   76.423   3600523   5937.029526
# 2      Algeria    Africa   72.301  33333216   6223.367465
# 3       Angola    Africa   42.731  12420476   4797.231267
# 4    Argentina  Americas   75.320  40301927  12779.379640

# %%
gdp_df.describe()
# Out:
#           lifeExp           pop     gdpPercap
# count  142.000000  1.420000e+02    142.000000
# mean    67.007423  4.402122e+07  11680.071820
# std     12.073021  1.476214e+08  12859.937337
# min     39.613000  1.995790e+05    277.551859
# 25%     57.160250  4.508034e+06   1624.842248
# 50%     71.935500  1.051753e+07   6124.371108
# 75%     76.413250  3.121004e+07  18008.835640
# max     82.603000  1.318683e+09  49357.190170

# %% [markdown]
# ## Part 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.set_style("ticks")

# %%
plt.figure(figsize=(15, 8))
#sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False);
sns.scatterplot(x="gdpPercap", y="lifeExp", hue='continent',size ='pop',
                 sizes=(80, 5000),data=gdp_df, alpha=0.7);#, legend=False);


#linewidth=0, edgecolor=None
#palette=sns.color_palette(['red', 'blue','black', 'green', 'white'])

# %%
# YOUR PLOT HERE
sns.scatterplot(x="total_bill", y="tip", hue='smoker', size="size",
                palette=sns.color_palette(["#2ecc71", "#e74c3c"]),
                sizes=(10, 300), data=tips_df, legend='False')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5346/2250125470.py in <module>
#       2 sns.scatterplot(x="total_bill", y="tip", hue='smoker', size="size",
#       3                 palette=sns.color_palette(["#2ecc71", "#e74c3c"]),
# ----> 4                 sizes=(10, 300), data=tips_df, legend='False')
#
# NameError: name 'tips_df' is not defined

# %% [markdown]
# ## Part 2

# %%
# YOUR PLOT HERE

# %% [markdown]
# ## 3. Interactive plot with plotly

# %%
# Import plotly express

# %%
# YOUR PLOT HERE
